# %%
# %run "/Workspace/Users/shaikhfaraz0401@gmail.com/CardPulse: Credit Card Analytics Lakehouse/00 Configuration"
# Out:
# ### This Notebook is used to do Configurations and set PATHs for project
# 2026-08-06 12:18:23,399 | INFO | Metadata table already exists. Skipping creation. ✅

# %%
# %run "/Workspace/Users/shaikhfaraz0401@gmail.com/CardPulse: Credit Card Analytics Lakehouse/01 ingest_to_bronze"
# Out:
# ### This Notebook is used to do Configurations and set PATHs for project
# 2026-08-06 12:18:30,809 | INFO | Metadata table already exists. Skipping creation. ✅
# ### Building Moduldar Function for API-Ingestation
# ### Function for Ingesting our data
# 2026-08-06 12:18:32,511 | INFO | Ingest to Bronze Orchestration Pipeline Started...
# 2026-08-06 12:18:32,512 | INFO | Merchants ingestion started...
# 2026-08-06 12:18:37,622 | INFO | 800 Rows ingested and saved to bronze/merchants
# 2026-08-06 12:18:37,623 | INFO | Customers ingestion started...
# 2026-08-06 12:18:38,120 | INFO | Starting API ingestion for /customers...
# 2026-08-06 12:18:38,121 | INFO | Fetching /customers page with offset=0
# 2026-08-06 12:19:02,949 | INFO | 0 rows fetched successfully.
# 2026-08-06 12:19:02,950 | INFO | No new rows found.
# 2026-08-06 12:19:02,950 | INFO | No new customer records, thus exiting the pipeline.
# 2026-08-06 12:19:02,951 | INFO | Cards ingestion started...
# ...

# %%
# %run "/Workspace/Users/shaikhfaraz0401@gmail.com/CardPulse: Credit Card Analytics Lakehouse/02 bronze_to_silver"
# Out:
# ### This Notebook is used to do Configurations and set PATHs for project
# 2026-08-06 12:19:15,878 | INFO | Metadata table already exists. Skipping creation. ✅
# #### Moduldar Functions which will be used by each processing pipelines
# ### Pipeline specific functions
# #### Functions for Merchants
# #### Functions for Customers
# #### Functions for Cards
# #### Functions for Transactions
# ### Orchestration Pipeline
# 2026-08-06 12:19:18,667 | INFO | Bronze to Silver Orchestration Pipeline Started...
# 2026-08-06 12:19:18,669 | INFO | Processing Merchants for Silver Started..
# 2026-08-06 12:19:19,186 | INFO | 800 Rows loaded from bronze merchants for silver processing
# 2026-08-06 12:19:20,924 | INFO |
# ...
#             DATA QUALITY & LINAGE REPORT
# ...
#
#         New Rows loaded from bronze : 800
#         Rows Removed While Cleaning : 0
#         Rows Entered in Validation : 800
#         Rows Passed in Validation & Loaded into Silver  : 800
# ...

# %%
# %run "/Workspace/Users/shaikhfaraz0401@gmail.com/CardPulse: Credit Card Analytics Lakehouse/03 silver_to_gold"
# Out:
# ### This Notebook is used to do Configurations and set PATHs for project
# 2026-08-06 12:32:56,759 | INFO | Metadata table already exists. Skipping creation. ✅
# #### Modular Function used by each functions
# #### Customer Spending Summary
# #### Portfolio Health
# #### Customer Segmentation
# 2026-08-06 12:33:00,153 | INFO | Silver to Gold Orchestration Pipeline Started...
# 2026-08-06 12:33:00,154 | INFO | Processing Customer Spending Started....
# 2026-08-06 12:33:04,942 | INFO | 90751 Rows Sucessfully saved to gold/customers_spend_summary
# 2026-08-06 12:33:10,261 | INFO | Successfully Processed Customer Spending.
# 2026-08-06 12:33:10,262 | INFO | Processing Portfolio Risk Summary Started...
# 2026-08-06 12:33:13,332 | INFO | 17000 Rows Sucessfully saved to gold/portfolio_risk_summary
# 2026-08-06 12:33:18,110 | INFO | Successfully Processed Portfolio Risk Summary.
# 2026-08-06 12:33:18,111 | INFO | Processing Customer Segmentation Started...
# ...
